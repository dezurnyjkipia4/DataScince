# %%
#Датасет: Анализ данных «Uber»

# %%
# Загрузка датасета «Uber» и просмотр
data = pd.read_csv("Uber.csv")
#data = pd.read_csv("electronic.csv")
data.head() # посмотрим на данные
# Out:
#   dispatching_base_number      date  active_vehicles  trips
# 0                  B02512  1/1/2015              190   1132
# 1                  B02765  1/1/2015              225   1765
# 2                  B02764  1/1/2015             3427  29421
# 3                  B02682  1/1/2015              945   7679
# 4                  B02617  1/1/2015             1228   9537

# %%
# Импортирует библиотеки для работы и подгружаем data_loader.py data_loader, data_preprocess, visualization
import data_loader as dl
import data_preprocess as dp
import visualization as vz

# Загрузка данных
file_path = 'Uber.csv'  # Замените на путь к вашему CSV файлу
#file_path = 'electronic.csv'  # Замените на путь к вашему CSV файлу
def load_data(file_path):

    return pd.read_csv(file_path)

# %%
# Подсчет пропусков по столбцам
dp.count_missing(data)
# Out:
# dispatching_base_number    0
# date                       0
# active_vehicles            0
# trips                      0
# dtype: int64

# %%
#отчёт о пропущенных значениях: столбец, количество, процент метод из data_preprocess.py
dp.missing_report(data)
# Out:
# Empty DataFrame
# Columns: [Пропущено, Процент]
# Index: []

# %%
# Визуализация
vz = DataVisualizer(rows=1, cols=1, figsize=(10,10))
vz.add_histogram(data, column='dispatching_base_number', bins=30, color='skyblue', edgecolor='black')
# Вывод-все работают одинаково.

vz = DataVisualizer(rows=1, cols=1, figsize=(10,10))
vz.add_line_plot(data, x='active_vehicles', y='trips', color='green')

vz = DataVisualizer(rows=1, cols=1, figsize=(10,10))
vz.add_scatter_plot(data, x='dispatching_base_number', y='active_vehicles', alpha=1, color='red')
# Out:
# All subplots filled.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3921556015.py in <cell line: 0>()
#       5
#       6 vz = DataVisualizer(rows=1, cols=1, figsize=(10,10))
# ----> 7 vz.add_line_plot(data, x='active_vehicles', y='trips', color='green')
#       8
#       9 vz = DataVisualizer(rows=1, cols=1, figsize=(10,10))
#
# TypeError: DataVisualizer.add_line_plot() got an unexpected keyword argument 'x'
